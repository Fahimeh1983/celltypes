# %%
import csv
import pandas as pd
import csv
import numpy as np
import matplotlib.pylab as plt
import scipy.spatial as ss

from sklearn.manifold import TSNE
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ### CMD scale function

# %%
from __future__ import division
 
import numpy as np
 
def cmdscale(D):
    """                                                                                       
    Classical multidimensional scaling (MDS)                                                  
                                                                                               
    Parameters                                                                                
    ----------                                                                                
    D : (n, n) array                                                                          
        Symmetric distance matrix.                                                            
                                                                                               
    Returns                                                                                   
    -------                                                                                   
    Y : (n, p) array                                                                          
        Configuration matrix. Each column represents a dimension. Only the                    
        p dimensions corresponding to positive eigenvalues of B are returned.                 
        Note that each dimension is only determined up to an overall sign,                    
        corresponding to a reflection.                                                        
                                                                                               
    e : (n,) array                                                                            
        Eigenvalues of B.                                                                     
                                                                                               
    """
    # Number of points                                                                        
    n = len(D)
 
    # Centering matrix                                                                        
    H = np.eye(n) - np.ones((n, n))/n
 
    # YY^T                                                                                    
    B = -H.dot(D**2).dot(H)/2
 
    # Diagonalize                                                                             
    evals, evecs = np.linalg.eigh(B)
 
    # Sort by eigenvalue in descending order                                                  
    idx   = np.argsort(evals)[::-1]
    evals = evals[idx]
    evecs = evecs[:,idx]
 
    # Compute the coordinates using positive-eigenvalued components only                      
    w, = np.where(evals > 0)
    L  = np.diag(np.sqrt(evals[w]))
    V  = evecs[:,w]
    Y  = V.dot(L)
 
    return Y, evals

# %% [markdown]
# ### Path to data and output

# %%
# Path
data_dir = "/Volumes/programs/celltypes/workgroups/rnaseqanalysis/Fahimehb/GNN/datasets/"
Output_dir = "/Volumes/programs/celltypes/workgroups/rnaseqanalysis/Fahimehb/GNN/Outputs/"

# %% [markdown]
# ### Read inputs

# %%
cl_df = pd.read_csv(data_dir + "cl_df_150cl.csv", index_col = "Unnamed: 0")
#JSD = pd.read_csv(data_dir + "facs_jsd_117cl.csv", index_col = "Unnamed: 0")
JSD = pd.read_csv(Output_dir + "/jsd_python_recomputed.csv", index_col = "Unnamed: 0")

# %%
cl_df.shape
# Out:
# (150, 14)

# %% [markdown]
# Cluster colors for plotting

# %%
colors = []
for cl in JSD.index.tolist():
    idx = cl_df[cl_df['cluster_label']==cl].index.tolist()[0]
    c = cl_df.iloc[idx]['cluster_color']
    colors.append(c)

# %%
types = JSD.index.tolist()

# %%
JSD.head()
# Out:
#                       L2/3 IT VISp Rrad  L2/3 IT VISp Adamts2  \
# L2/3 IT VISp Rrad              0.000000              0.128188
# L2/3 IT VISp Adamts2           0.128188              0.000000
# L2/3 IT VISp Agmat             0.117595              0.045904
# L2/3 IT ALM Sla                0.170168              0.041612
# L2/3 IT ALM Ptrf               0.185938              0.088259
#
#                       L2/3 IT VISp Agmat  L2/3 IT ALM Sla  L2/3 IT ALM Ptrf  \
# L2/3 IT VISp Rrad               0.117595         0.170168          0.185938
# L2/3 IT VISp Adamts2            0.045904         0.041612          0.088259
# L2/3 IT VISp Agmat              0.000000         0.059939          0.043409
# L2/3 IT ALM Sla                 0.059939         0.000000          0.047090
# L2/3 IT ALM Ptrf                0.043409         0.047090          0.000000
#
#                       L2/3 IT ALM Macc1 Lrg1  L4 IT VISp Rspo1  \
# L2/3 IT VISp Rrad                   0.177878          0.286164
# ...

# %% [markdown]
# ### Apply CMD scale on JSD matrix

# %%
[Y,eigvals] = cmdscale(np.array(JSD))
#eigvals/max(abs(eigvals))

# %% [markdown]
# There are 37 positive eigenvalues in B matrix and therefore the shape of the Y has 93 by 37 dimensions

# %% [markdown]
# ### Plotting the eigenvalues of the B matrix

# %% [markdown]
# Positive eigen values and eigenvectors of B matrix will define the coordinate of the nodes for which we provided JSD matrix

# %%
plt.figure(figsize=(10,8))
plt.scatter(x = range(len(eigvals)), y = eigvals/max(abs(eigvals)))

# %%
import cell
import imp
from cell import plot_utils

imp.reload(cell)
imp.reload(plot_utils)
# Out:
# <module 'cell.plot_utils' from '/Users/fahimehb/Documents/git-workspace/celltypes/cell/plot_utils.py'>

# %% [markdown]
# As the first 4(or 2) eigenvalues are much larger than the rest, maybe those are sufficient to explain the coordinates

# %%
from cell import plot_utils

plot_utils.Plot_3D(xyz= Y, 
                   colors= colors, 
                   annotation= None, 
                   theta1= 30, 
                   theta2= 60,
                  plot_size = (20,20))

# %%
from cell import plot_utils

plot_utils.Plot_3D(xyz= Y, 
                   colors= colors, 
                   annotation= types, 
                   theta1= 30, 
                   theta2= 60,
                  plot_size = (20,20))

# %%
import csv
emb = pd.DataFrame(Y, index= types, columns=["Z"+ str(i) for i in range(Y.shape[1])])
emb.to_csv(Output_dir + "/CMDscale_emb.csv")

# %% [markdown]
# ### Compute the cosine distance matrix between types

# %%
cosine_distance = {}

for i, c1 in enumerate(Y):
    type1 = types[i] 
    for j, c2 in enumerate(Y):
        type2 = types[j]
        cosine_distance[(type1, type2)] = [ss.distance.cosine(c1, c2)]

# %% [markdown]
# ### Find the most similar node to a given node

# %%
given_type = 'Sst Crh 4930553C11Rik '
dist_from_node = []

for i in types:
    dist_from_node.append((i, cosine_distance[(given_type, i)]))

def Sort_Tuple(tup):  
    lst = len(tup)  
    for i in range(0, lst):  
        for j in range(0, lst-i-1):  
            if (tup[j][1] > tup[j + 1][1]):  
                temp = tup[j]  
                tup[j]= tup[j + 1]  
                tup[j + 1]= temp  
    return tup  

Sort_Tuple(dist_from_node)[1:10]
# Out:
# [('Sst Crhr2 Efemp1', [0.031717391491294156]),
#  ('Sst Esm1', [0.050138211986780035]),
#  ('Sst Mme Fam114a1', [0.09534082897435558]),
#  ('Sst Myh8 Etv1 ', [0.10182395966347368]),
#  ('Sst Hpse Cbln4', [0.10770837149757984]),
#  ('Sst Calb2 Pdlim5', [0.11662181073926803]),
#  ('Sst Nts', [0.13149870666388286]),
#  ('Sst Tac2 Myh4', [0.13249746031388188]),
#  ('Sst Nr2f2 Necab1', [0.15319440505141402])]

# %% [markdown]
# ### Save the results

# %%
df = pd.DataFrame(cosine_distance).T
df.to_csv(Output_dir + "CMDscale_cosine_distance.csv",
          index=True,
          header=False,
          mode='a')

# %%
df.head()
# Out:
#                                                0
# L2/3 IT VISp Rrad L2/3 IT VISp Rrad     0.000000
#                   L2/3 IT VISp Adamts2  0.118054
#                   L2/3 IT VISp Agmat    0.080774
#                   L2/3 IT ALM Sla       0.158059
#                   L2/3 IT ALM Ptrf      0.162223
