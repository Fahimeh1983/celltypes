# %%
import scipy.io as sio
import sklearn as sk
import operator
import json
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
from gensim.models import Word2Vec
from scipy.stats import multivariate_normal

# %%
work_dir = "/Volumes/Fahimehb/GNN/"

# %% [markdown]
# ## Read the embeddings:

# %%
D = sio.loadmat('2d_representation.mat', squeeze_me=True)
plt.scatter(x=D['z'][:, 0], y=D['z'][:, 1], s=1, c=D['color'])

# %% [markdown]
# Add cluster id and put the coordinates, cluster_ids and colors into a data frame

# %%
D['cluster_id'] = pd.factorize(D['cluster'])[0]

# %%
types = np.unique(D['cluster'])
type_ids = np.unique(D['cluster_id'])

# %%
df = pd.concat([pd.DataFrame(D['z']), 
                pd.DataFrame(D['cluster']), 
                pd.DataFrame(D['cluster_id']),
                pd.DataFrame(D['color'])], axis=1)
df.columns = ["x", "y", "cluster", "cluster_id", "cluster_color"]

# %%
df
# Out:
#               x         y                 cluster  cluster_id cluster_color
# 0      0.369958 -0.594060      L2/3 IT VISp Agmat           0       #7AE6AB
# 1      0.567149  0.727586             Pvalb Vipr2           1       #FF197F
# 2     -1.340917  0.715800        Vip Igfbp6 Car10           2       #7779BF
# 3      0.461240 -0.610380  L2/3 IT ALM Macc1 Lrg1           3       #ADE6A6
# 4      1.561296  0.399310   L6b VISp Col8a1 Rxfp1           4       #388899
# ...         ...       ...                     ...         ...           ...
# 24406  0.297967 -1.302966        L4 IT VISp Rspo1          42       #00979D
# 24407 -1.697436 -2.092990             Endo Ctla2a          38       #997F7A
# 24408  0.061318 -1.123602        L4 IT VISp Rspo1          42       #00979D
# 24409 -0.399719  1.397918        Sst Calb2 Pdlim5          53       #CC6D3D
# 24410 -1.546328  0.003857       Vip Col15a1 Pde1a          97       #AC3491
#
# [24411 rows x 5 columns]

# %% [markdown]
# ## Compute moments of each distribution

# %%
mu_dict = {}
cov_dict = {}

for c in types:
    X_c = np.array(df[df['cluster'] == c][["x","y"]])
    X_c = X_c.T
    cov = np.cov(X_c) #compute covariance matrix
    mu = np.mean(X_c, axis=1) #compute mean vector
    mu_dict[c] = mu
    cov_dict[c] = cov

# %%
mu_dict
# Out:
# {'Astro Aqp4': array([-0.66269356, -1.7065222 ], dtype=float32),
#  'Batch Grouping VISp L5 PT Chrna6': array([ 1.1872478, -0.4844831], dtype=float32),
#  'Batch Grouping VISp L5 PT Ctxn3': array([ 1.3370998 , -0.42498502], dtype=float32),
#  'CR Lhx5': array([-0.73897237, -0.23296414], dtype=float32),
#  'Doublet Astro Aqp4 Ex': array([-0.80094016, -1.8874146 ], dtype=float32),
#  'Doublet Endo Peri SMC': array([-2.3208919, -1.9480028], dtype=float32),
#  'Doublet Endo and Peri_1': array([-1.8839679, -1.7771612], dtype=float32),
#  'Doublet SMC and Glutamatergic': array([-1.9981409, -1.3615652], dtype=float32),
#  'Doublet VISp L5 NP and L6 CT': array([0.7757471 , 0.45508364], dtype=float32),
#  'Endo Ctla2a': array([-1.2817026, -1.5250318], dtype=float32),
#  'Endo Cytl1': array([-1.145836 , -1.3055128], dtype=float32),
#  'High Intronic VISp L5 Endou': array([ 0.20760484, -1.9936471 ], dtype=float32),
#  'L2/3 IT ALM Macc1 Lrg1': array([ 0.501168 , -0.6760681], dtype=float32),
#  'L2/3 IT ALM Ptrf': array([ 0.48105186, -0.6345465 ], dtype=float32),
#  'L2/3 IT ALM Sla': array([ 0.49807435, -0.64173573], dtype=float32),
#  'L2/3 IT VISp Adamts2': array([ 0.33301634, -0.54045546], dtype=float32),
#  'L2/3 IT VISp Agmat': array([ 0.32332653, -0.5765599 ], dtype=float32),
#  'L2/3 IT VISp Rrad': array([ 0.15599068, -0.44306338], dtype=float32),
#  'L4 IT VISp Rspo1': array([ 0.15790105, -1.3241283 ], dtype=float32),
#  'L5 IT ALM Cbln4 Fezf2': array([ 0.8225967, -1.525126 ], dtype=float32),
#  'L5 IT ALM Cpa6 Gpr88': array([ 0.96525055, -1.0939602 ], dtype=float32),
#  'L5 IT ALM Gkn1 Pcdh19': array([ 1.065632 , -1.0346773], dtype=float32),
#  'L5 IT ALM Lypd1 Gpr88': array([ 0.8624831, -1.6110862], dtype=float32),
#  'L5 IT ALM Npw': array([ 0.7765629, -1.375693 ], dtype=float32),
#  'L5 IT ALM Pld5': array([ 0.71730864, -1.613736  ], dtype=float32),
#  'L5 IT ALM Tmem163 Arhgap25': array([ 1.1580656, -1.1978465], dtype=float32),
#  'L5 IT ALM Tmem163 Dmrtb1': array([ 1.1905851, -1.4140761], dtype=float32),
#  'L5 IT ALM Tnc': array([ 1.061368 , -1.5212773], dtype=float32),
#  'L5 IT VISp Batf3': array([ 0.38496017, -0.93632054], dtype=float32),
#  'L5 IT VISp Col27a1': array([ 0.7057177, -1.0355818], dtype=float32),
#  'L5 IT VISp Col6a1 Fezf2': array([ 0.49329722, -0.9949611 ], dtype=float32),
#  'L5 IT VISp Hsd11b1 Endou': array([ 0.38485414, -1.1788074 ], dtype=float32),
#  'L5 IT VISp Whrn Tox2': array([ 0.45066813, -1.068931  ], dtype=float32),
#  'L5 NP ALM Trhr Nefl': array([0.82475233, 0.64362925], dtype=float32),
#  'L5 NP VISp Trhr Cpne7': array([0.7649843 , 0.45826793], dtype=float32),
#  'L5 NP VISp Trhr Met': array([0.71880585, 0.54376537], dtype=float32),
#  'L5 PT ALM Hpgd': array([ 1.575847  , -0.27959085], dtype=float32),
#  'L5 PT ALM Npsr1': array([ 1.641461  , -0.29935348], dtype=float32),
#  'L5 PT ALM Slco2a1': array([ 1.6439536 , -0.21842264], dtype=float32),
#  'L5 PT VISp C1ql2 Cdh13': array([ 1.411669  , -0.42061448], dtype=float32),
#  'L5 PT VISp C1ql2 Ptgfr': array([ 1.4045883 , -0.45083293], dtype=float32),
#  'L5 PT VISp Chrna6': array([ 1.193534 , -0.5083123], dtype=float32),
#  'L5 PT VISp Krt80': array([ 1.4139068 , -0.41002557], dtype=float32),
#  'L5 PT VISp Lgr5': array([ 1.4138986 , -0.49812892], dtype=float32),
#  'L6 CT ALM Cpa6': array([1.2057476 , 0.14278874], dtype=float32),
#  'L6 CT Nxph2 Sla': array([1.2266252 , 0.09949636], dtype=float32),
#  'L6 CT VISp Ctxn3 Brinp3': array([ 1.1832819 , -0.03292347], dtype=float32),
#  'L6 CT VISp Ctxn3 Sla': array([ 1.1451709 , -0.01642864], dtype=float32),
#  'L6 CT VISp Gpr139': array([1.2355489 , 0.11244258], dtype=float32),
#  'L6 CT VISp Krt80 Sla': array([1.2120866 , 0.11800957], dtype=float32),
#  'L6 CT VISp Nxph2 Wls': array([1.1082143 , 0.01432056], dtype=float32),
#  'L6 IT ALM Oprk1': array([ 0.7710329 , -0.73166543], dtype=float32),
#  'L6 IT ALM Tgfb1': array([ 0.9598641 , -0.89070386], dtype=float32),
#  'L6 IT VISp Car3': array([ 0.6211105 , -0.59751743], dtype=float32),
#  'L6 IT VISp Col18a1': array([ 0.7688868 , -0.25886002], dtype=float32),
#  'L6 IT VISp Col23a1 Adamts2': array([ 0.71564037, -0.28077897], dtype=float32),
#  'L6 IT VISp Penk Col27a1': array([ 0.6778397 , -0.43642783], dtype=float32),
#  'L6 IT VISp Penk Fst': array([ 0.61731714, -0.2614081 ], dtype=float32),
#  'L6 NP ALM Trh': array([1.0746076, 0.6331272], dtype=float32),
#  'L6b ALM Olfr111 Nxph1': array([1.3711087, 0.5969228], dtype=float32),
#  'L6b ALM Olfr111 Spon1': array([1.3898412 , 0.50306475], dtype=float32),
#  'L6b Col8a1 Rprm': array([1.3147364 , 0.32518074], dtype=float32),
#  'L6b Hsd17b2': array([1.4264545, 0.5829695], dtype=float32),
#  'L6b P2ry12': array([1.4627516, 0.6387475], dtype=float32),
#  'L6b VISp Col8a1 Rxfp1': array([1.3597325 , 0.39646432], dtype=float32),
#  'L6b VISp Crh': array([1.4178704, 0.5435053], dtype=float32),
#  'L6b VISp Mup5': array([1.4094282, 0.4165616], dtype=float32),
#  'Lamp5 Fam19a1 Pax6': array([-1.6962893,  1.1818126], dtype=float32),
#  'Lamp5 Fam19a1 Tmem182': array([-1.54976  ,  1.1547488], dtype=float32),
#  'Lamp5 Krt73': array([-1.8246565,  1.2723672], dtype=float32),
#  'Lamp5 Lhx6': array([-1.0862948,  1.2532473], dtype=float32),
#  'Lamp5 Lsp1': array([-1.1762948,  1.344544 ], dtype=float32),
#  'Lamp5 Ntn1 Npy2r': array([-1.3229825 ,  0.99846464], dtype=float32),
#  'Lamp5 Plch2 Dock5': array([-1.21785  ,  1.0863764], dtype=float32),
#  'Low Quality ALM L6 CT Cpa6': array([-0.23253612, -0.85386986], dtype=float32),
#  'Low Quality Astro Aqp4': array([-0.76820314, -1.256231  ], dtype=float32),
#  'Low Quality L4 Rspo1': array([-0.19692624, -1.7712945 ], dtype=float32),
#  'Low Quality Meis2 Adamts19 ': array([-0.29123357, -0.7068226 ], dtype=float32),
#  'Low Quality Sst Chodl': array([-0.7073633,  1.805241 ], dtype=float32),
#  'Low Quality VISp L5 PT Ctxn3 1': array([ 0.1620183 , -0.01465538], dtype=float32),
#  'Low Quality VISp L5 PT Ctxn3 2': array([ 1.1094449, -0.3947885], dtype=float32),
#  'Low Quality VISp L6 CT Ptprt_1': array([-0.99888504, -0.40154004], dtype=float32),
#  'Low Quality VISp L6 CT Ptprt_2': array([-0.09808695, -0.15781236], dtype=float32),
#  'Meis2 Adamts19': array([-0.3970271 ,  0.02711953], dtype=float32),
#  'Microglia Siglech': array([-0.76581603, -0.6653952 ], dtype=float32),
#  'OPC Pdgfra Ccnb1': array([-1.8305311 , -0.15999609], dtype=float32),
#  'OPC Pdgfra Grm5': array([-0.8349816, -0.3955784], dtype=float32),
#  'Oligo Rassf10': array([-2.5132484, -0.3100074], dtype=float32),
#  'Oligo Serpinb1a': array([-1.4925992, -0.4542248], dtype=float32),
#  'Oligo Synpr': array([-2.341777 , -0.4456583], dtype=float32),
#  'PVM Mrc1': array([-1.9787891, -0.6945259], dtype=float32),
#  'Peri Kcnj8': array([-1.27523  , -1.0386703], dtype=float32),
#  'Pvalb Akr1c18 Ntf3': array([0.20284708, 0.99755204], dtype=float32),
#  'Pvalb Calb1 Sst': array([0.21972707, 0.9736866 ], dtype=float32),
#  'Pvalb Gabrg1': array([0.07298547, 0.7896401 ], dtype=float32),
#  'Pvalb Gpr149 Islr': array([0.24473202, 0.9119393 ], dtype=float32),
#  'Pvalb Reln Itm2a': array([0.4354784, 0.92558  ], dtype=float32),
#  'Pvalb Reln Tac1': array([0.3396601, 0.8511028], dtype=float32),
#  'Pvalb Sema3e Kank4': array([0.29610893, 1.0695373 ], dtype=float32),
#  'Pvalb Th Sst': array([0.1178921 , 0.96060014], dtype=float32),
#  'Pvalb Tpbg': array([0.569225 , 0.9120098], dtype=float32),
#  'Pvalb Vipr2': array([0.5925097, 0.7655289], dtype=float32),
#  'SMC Acta2': array([-1.7887938, -1.2614313], dtype=float32),
#  'Serpinf1 Aqp5 Vip': array([-1.6105671,  0.3592812], dtype=float32),
#  'Serpinf1 Clrn1': array([-1.7849487,  1.2195035], dtype=float32),
#  'Sncg Gpr50': array([-2.1314557,  1.3029113], dtype=float32),
#  'Sncg Slc17a8': array([-2.234325 ,  1.2169472], dtype=float32),
#  'Sncg Vip Itih5': array([-2.0982003,  1.1392974], dtype=float32),
#  'Sncg Vip Nptx2': array([-1.8935019,  1.1222153], dtype=float32),
#  'Sst Calb2 Necab1': array([-0.29416573,  1.0591979 ], dtype=float32),
#  'Sst Calb2 Pdlim5': array([-0.36233225,  1.0968709 ], dtype=float32),
#  'Sst Chodl': array([-0.7692487,  2.056611 ], dtype=float32),
#  'Sst Chrna2 Glra3': array([-0.680762  ,  0.91913944], dtype=float32),
#  'Sst Chrna2 Ptgdr': array([-0.5553032 ,  0.93183476], dtype=float32),
#  'Sst Crh 4930553C11Rik ': array([-0.15080851,  1.2835442 ], dtype=float32),
#  'Sst Crhr2 Efemp1': array([-0.19623953,  1.2527146 ], dtype=float32),
#  'Sst Esm1': array([-0.1885253,  1.3479599], dtype=float32),
#  'Sst Hpse Cbln4': array([-0.39819515,  1.0745375 ], dtype=float32),
#  'Sst Hpse Sema3c': array([-0.4073453 ,  0.84669304], dtype=float32),
#  'Sst Mme Fam114a1': array([-0.2356196,  1.208695 ], dtype=float32),
#  'Sst Myh8 Etv1 ': array([-0.7077565,  1.0312967], dtype=float32),
#  'Sst Myh8 Fibin': array([-0.7156762,  0.8606886], dtype=float32),
#  'Sst Nr2f2 Necab1': array([-0.3095557,  1.1473984], dtype=float32),
#  'Sst Nts': array([-0.03371038,  1.1018821 ], dtype=float32),
#  'Sst Rxfp1 Eya1': array([0.00317187, 1.1569874 ], dtype=float32),
#  'Sst Rxfp1 Prdm8': array([0.04517847, 1.2433449 ], dtype=float32),
#  'Sst Tac1 Htr1d': array([-0.20920108,  1.0002887 ], dtype=float32),
#  'Sst Tac1 Tacr3': array([-0.00216685,  0.7597211 ], dtype=float32),
#  'Sst Tac2 Myh4': array([-0.47043982,  1.1384774 ], dtype=float32),
#  'Sst Tac2 Tacstd2': array([-0.00846575,  1.2567188 ], dtype=float32),
#  'VLMC Osr1 Cd74': array([-2.6721942, -1.2579123], dtype=float32),
#  'VLMC Osr1 Mc5r': array([-1.8274143, -0.8888279], dtype=float32),
#  'VLMC Spp1 Col15a1': array([-1.867794  , -0.90287286], dtype=float32),
#  'VLMC Spp1 Hs3st6': array([-1.6566727, -0.868704 ], dtype=float32),
#  'Vip Arhgap36 Hmcn1': array([-1.3097874 ,  0.45788676], dtype=float32),
#  'Vip Chat Htr1f': array([-1.4302437 ,  0.12673807], dtype=float32),
#  'Vip Col15a1 Pde1a': array([-1.6470051 ,  0.20271048], dtype=float32),
#  'Vip Crispld2 Htr2c': array([-1.5441961 , -0.02846392], dtype=float32),
#  'Vip Crispld2 Kcne4': array([-1.7925447 , -0.02929325], dtype=float32),
#  'Vip Gpc3 Slc18a3': array([-1.3232106 ,  0.42242712], dtype=float32),
#  'Vip Igfbp4 Mab21l1': array([-1.0895339,  0.3463872], dtype=float32),
#  'Vip Igfbp6 Car10': array([-1.1997976,  0.5535528], dtype=float32),
#  'Vip Igfbp6 Pltp': array([-1.0535371 ,  0.50472254], dtype=float32),
#  'Vip Lect1 Oxtr': array([-1.4862269 ,  0.14665395], dtype=float32),
#  'Vip Lmo1 Fam159b': array([-1.4950352 ,  0.35544592], dtype=float32),
#  'Vip Lmo1 Myl1': array([-1.5181926 ,  0.30985343], dtype=float32),
#  'Vip Ptprt Pkp2': array([-1.2864201 ,  0.26746482], dtype=float32),
#  'Vip Pygm C1ql1': array([-1.4085166,  0.2736072], dtype=float32),
#  'Vip Rspo1 Itga4': array([-1.3616633,  0.1083913], dtype=float32),
#  'Vip Rspo4 Rxfp1 Chat': array([-1.3268738 ,  0.19694048], dtype=float32)}

# %% [markdown]
# For future reference, create a cl_df which has all the cluster properties:

# %%
color_dict = {}

for c in types:
    color = np.unique(df[df['cluster'] == c]["cluster_color"])
    color_dict[c] = color[0]

# %%
cl_df = pd.DataFrame()
mu_x = []
mu_y = []
color = []

for c in types:
    mu_x.append(mu_dict[c][0])
    mu_y.append(mu_dict[c][1])
    color.append(color_dict[c])

cl_df['cluster'] = types
cl_df['cluster_id'] = type_ids
cl_df['cluster_color'] = color
cl_df['mu_x'] = mu_x
cl_df['mu_y'] = mu_y

# %%
cl_df.to_csv("/Volumes/programs/celltypes/workgroups/rnaseqanalysis/Fahimehb/GNN/datasets/cl_df.csv")

# %%
plt.figure(figsize=(5,5))
plt.scatter(x = cl_df['mu_x'], y = cl_df['mu_y'], color = cl_df['cluster_color'])

# %% [markdown]
# ## Generate random walks based on mu and cov

# %%
def Generate_Random_Sample(mu, cov):
    y = np.random.multivariate_normal(mu, cov)
    return y

def Compute_Likelihood(mu, cov, sample):
    LL = multivariate_normal.pdf(x=sample, mean=mu, cov=cov)
    return LL

def Get_Max_LL(LL):
    next_node = max(LL.items(), key=operator.itemgetter(1))[0]
    return next_node

def Get_Next_Node_LL(types, mu_dict, cov_dict, sample):
    sample_LL_scores = {}
    for n in types:
        tmp_mu = mu_dict[n]
        tmp_cov = cov_dict[n]
        LL = Compute_Likelihood(tmp_mu, tmp_cov, sample)
        sample_LL_scores[n] = LL
    next_node = Get_Max_LL(sample_LL_scores)
    return next_node

def Get_Next_Node_KDtree(random_sample, emb, df):
    random_sample_index = emb.shape[0]
    tmp_emb = np.append(emb, [random_sample], axis=0)
    tree = KDTree(tmp_emb)
    nearest_dist, nearest_ind = tree.query(tmp_emb, k=5)
    nn_index_to_random_sample = nearest_ind[random_sample_index][1]
    next_node = df.iloc[nn_index_to_random_sample]['cluster']
    return next_node

# %%
n_nodes = len(types)
walk_length = 5
walk_per_node = 200

#random_walks = np.zeros(shape=(n_nodes*walk_per_node, walk_length))
random_walks = []                                                
for i in range (0, n_nodes*walk_per_node):                             
    new = []                  
    for j in range (0, walk_length):    
        new.append("")      
    random_walks.append(new)  

w = 0
for c in types:
    for w_p_n in range(walk_per_node):
        next_node = c
        walk = [next_node]
        w_l = 1
        while w_l < walk_length:
            mu = mu_dict[next_node]
            cov = cov_dict[next_node]
            random_sample =  Generate_Random_Sample(mu, cov)
            #next_node = Get_Next_Node_LL(types, mu_dict, cov_dict, random_sample)
            next_node = Get_Next_Node_KDtree(random_sample, D['z'], df)
            walk.append(next_node)
            w_l = w_l + 1
        random_walks[w] = walk
        w = w + 1

# %%
with open(work_dir + '/random_walks.json') as f:
    old_walks = json.load(f)
    
new_walk = old_walks + random_walks

with open(work_dir + '/random_walks.json', "w") as f:
    json.dump(new_walk, f)

# %%
len(new_walk)
# Out:
# 91500

# %%
model = Word2Vec(new_walk, min_count = 1, size=2, window=2, sg=1)
plt.figure(figsize=(5,5))
plt.scatter([model.wv[i][0] for i in types], [model.wv[i][1] for i in types], color = color)

# %%
model.wv.most_similar("Vip Pygm C1ql1")
# Out:
# [('Microglia Siglech', 0.9999793171882629),
#  ('Sst Tac1 Htr1d', 0.9994059205055237),
#  ('Vip Lmo1 Fam159b', 0.9986574053764343),
#  ('Vip Ptprt Pkp2', 0.9983718395233154),
#  ('Sst Esm1', 0.9977049231529236),
#  ('PVM Mrc1', 0.9961682558059692),
#  ('Sst Crhr2 Efemp1', 0.9960218667984009),
#  ('Serpinf1 Aqp5 Vip', 0.9955883026123047),
#  ('Low Quality Astro Aqp4', 0.9950751066207886),
#  ('Sst Crh 4930553C11Rik ', 0.9939356446266174)]

# %%
cl_df
# Out:
#                               cluster  cluster_id cluster_color      mu_x  \
# 0                          Astro Aqp4           0       #665C47 -0.662694
# 1    Batch Grouping VISp L5 PT Chrna6           1       #231F20  1.187248
# 2     Batch Grouping VISp L5 PT Ctxn3           2       #414042  1.337100
# 3                             CR Lhx5           3       #00FF66 -0.738972
# 4               Doublet Astro Aqp4 Ex           4       #F1F2F2 -0.800940
# ..                                ...         ...           ...       ...
# 145                     Vip Lmo1 Myl1         145       #9FAAFF -1.518193
# 146                    Vip Ptprt Pkp2         146       #FF00FF -1.286420
# 147                    Vip Pygm C1ql1         147       #BD3D9A -1.408517
# 148                   Vip Rspo1 Itga4         148       #B3128A -1.361663
# 149              Vip Rspo4 Rxfp1 Chat         149       #AF00E6 -1.326874
#
#          mu_y
# 0   -1.706522
# 1   -0.484483
# 2   -0.424985
# 3   -0.232964
# 4   -1.887415
# ..        ...
# 145  0.309853
# 146  0.267465
# 147  0.273607
# 148  0.108391
# 149  0.196940
#
# [150 rows x 5 columns]

# %%
for walk in random_walks[50:100]:
    x = []
    y = []
    color = []
    for w in walk:
        idx = cl_df[cl_df['cluster_id']== w].index.tolist()[0]
        x.append(cl_df.loc[idx]['mu_x'])
        y.append(cl_df.loc[idx]['mu_y'])
        color.append(cl_df.loc[idx]['cluster_color'])
    plt.figure(figsize=(5,5))
    plt.scatter(x = cl_df['mu_x'], y = cl_df['mu_y'], color = "#DCDCDC")
    plt.scatter(x = x, y = y, color = color)
# Out:
# /Users/fahimehb/anaconda2/envs/python3/lib/python3.6/site-packages/matplotlib/pyplot.py:522: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
def cosine_distance (model, word, target_list, num) :
    cosine_dict ={}
    word_list = []
    a = model.wv[word]
    for item in types:
        if item != word :
            b = model.wv[item]
            cos_sim = np.dot(a, b)/(np.linalg.norm(a)*np.linalg.norm(b))
            cosine_dict[item] = cos_sim
            dist_sort=sorted(cosine_dict.items(), key=lambda dist: dist[1],reverse = True)
            for item in dist_sort:
                word_list.append((item[0], item[1]))
    return word_list[0:num]be
